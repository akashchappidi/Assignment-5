# %% [markdown]
# ASSIGNMENT
# 1) What is the difference between interpreted and compiled languages?
# -->Interpreted: Code is executed line-by-line by an interpreter, making it more flexible but generally slower.
# Compiled: Code is translated into machine code by a compiler before execution, resulting in faster performance but less flexibility.
#
# Q2)What is exception handling in Python?
# -->Exception handling is a mechanism to gracefully deal with errors that occur during program execution, such as invalid input or missing files.
# It uses try, except, finally blocks to catch and handle exceptions, preventing the program from crashing unexpectedly.
#
# Q3)What is the purpose of the finally block in exception handling?
# -->The finally block in Python's exception handling guarantees the execution of certain code, such as resource cleanup (e.g., closing files), irrespective of whether an exception occurs within the try block or not.
#
# Q4) What is logging in Python?
# -->Logging in Python is a mechanism for recording events and messages that occur during program execution. It provides a structured way to track errors, debug issues, and monitor the behavior of your application.
#
# Q5) What is the significance of the __del__ method in Python?
# --> The __del__ method, also known as the destructor, is a special method in Python that is called just before an object is garbage collected. It provides a mechanism for performing any necessary cleanup operations, such as closing files or releasing external resources, before the object is permanently removed from memory.
#
# Q6) What is the difference between import and from ... import in Python?
# -->import: Imports the entire module into the current namespace, requiring you to use the module name as a prefix (e.g., module_name.function()).
# from ... import: Imports specific objects (functions, classes, variables) directly into the current namespace, allowing you to use them without the module name prefix (e.g., function()).
#
# Q7) How can you handle multiple exceptions in Python?
# -->You can handle multiple exceptions in Python using multiple except blocks, each specifying a different exception type. Alternatively, you can use a single except block with a tuple of exception types to catch multiple exceptions in a concise way.
#
# Q8) What is the purpose of the with statement when handling files in Python?
# -->The with statement in Python simplifies file handling by automatically closing the file object even if exceptions occur within the with block. This ensures that resources are properly released, preventing potential errors and improving code maintainability.
#
# Q9) What is the difference between multithreading and multiprocessing?
# -->Multithreading: Executes multiple threads within a single process, sharing the same memory space. Suitable for I/O-bound tasks.
# Multiprocessing: Creates multiple processes, each with its own memory space. Better for CPU-bound tasks as it avoids the Global Interpreter Lock (GIL) in Python.
#
# Q10) What are the advantages of using logging in a program?
# -->Logging provides valuable insights into program behavior, aiding in debugging, monitoring, and understanding application performance. It helps identify and troubleshoot errors, track user activity, and analyze system usage patterns, enabling proactive maintenance and improvement.
#
# Q11) What is memory management in Python?
# -->Python's memory management handles allocation and deallocation of memory for objects automatically. It uses techniques like reference counting and garbage collection to efficiently manage memory, reducing the risk of memory leaks and simplifying development.
#
# Q12)What are the basic steps involved in exception handling in Python?
# -->try block: Enclose the code that might raise an exception.
# except block: Handle the raised exception by providing appropriate error handling logic.
#
# Q13) Why is memory management important in Python?
# -->Efficient memory management in Python prevents memory leaks, improves performance, and ensures the stability and reliability of applications by preventing unexpected crashes due to insufficient memory.
#
# Q14) What is the role of try and except in exception handling?
# -->try block: Contains the code that might raise an exception.
# except block: Handles the raised exception by executing specific code to recover or gracefully exit.
#
# Q15) How does Python's garbage collection system work?
# -->Python uses a combination of reference counting and a cyclic garbage collector to reclaim memory. Reference counting tracks the number of references to an object. When the count reaches zero, the object is immediately deallocated. The cyclic garbage collector handles cases where objects form circular references, preventing memory leaks.
#
# Q16)What is the purpose of the else block in exception handling?
# -->The else block in exception handling executes only if no exception occurs within the corresponding try block. It's useful for code that should run only when the try block completes successfully without encountering any errors.
#
# Q17)What are the common logging levels in Python?
# -->Common logging levels in Python include DEBUG, INFO, WARNING, ERROR, and CRITICAL, representing increasing severity of events. You can configure your logger to filter messages based on these levels, allowing you to control the amount of log information generated.
#
# Q18)What is the difference between os.fork() and multiprocessing in Python?
# -->os.fork(): Creates a child process that is an exact copy of the parent process, including memory and file descriptors. Primarily used for system-level forking.
# multiprocessing: Provides a higher-level API for creating and managing multiple processes, including features like process pools and message queues, making it easier to write concurrent programs.
#
# Q19)What is the importance of closing a file in Python?
# -->Closing a file explicitly using file_object.close() ensures that all buffered data is written to the file and system resources associated with the file are released, preventing potential data loss, resource leaks, and errors in subsequent operations.
#
# Q20)What is the difference between file.read() and file.readline() in Python?
# -->file.read(): Reads the entire content of the file into a single string. If you provide an argument (number of bytes), it reads that specific number of bytes.
#
# file.readline(): Reads a single line from the file, including the newline character (\n), and returns it as a string. It reads from the current position in the file up to the next newline character.
#
# Q21) What is the logging module in Python used for?
# -->The logging module in Python is used to generate and manage log messages during program execution. It provides a flexible and configurable way to record events, debug issues, and monitor application behavior.
#
# Q22) What is the os module in Python used for in file handling?
# -->The os module in Python provides functions for interacting with the operating system, including file system operations. It's used for tasks like:
#
# Path manipulation: Joining paths, getting file names, checking file existence.
# File and directory operations: Creating, renaming, deleting files and directories.
#
# Q23)What are the challenges associated with memory management in Python?
# -->Circular references: Objects can form circular references, making it difficult for the garbage collector to identify and reclaim unused memory.
# Memory leaks: Unintentional long-term retention of unused objects can lead to memory exhaustion, impacting performance and stability.
#
# Q24)How do you raise an exception manually in Python?
# -->raise ValueError("Invalid input value")
#
# Q25)Why is it important to use multithreading in certain applications?
# -->Multithreading can significantly improve performance in I/O-bound applications by allowing concurrent execution of I/O operations, such as network requests or file reads/writes, while the main thread continues to process other tasks, making the program more responsive and efficient.

# %%
'''
PRACTICAL QUESTIONS:

Q1)How can you open a file for writing in Python and write a string to it
with open("exe.txt","w") as f:
  f.write("hello ds team")

Q2) Write a Python program to read the contents of a file and print each line
with open("fil.txt","r") as f:
    print(f.readlines())

Q3)How would you handle a case where the file doesn't exist while trying to open it for reading
try:
    with open("devera.txt","r") as f:
        f.read()
except FileNotFoundError as e:
    print("file not found",e)

Q4)Write a Python script that reads from one file and writes its content to another file
a = open("devara.txt","r")
file = a.read()
print(file)

with open("nnn.txt","w") as d:
    d.write(file)
Q5)How would you catch and handle division by zero error in Python?
-->
try:
    3/0
except ZeroDivisionError as d:
    print("this is a error ", d)

Q6)Write a Python program that logs an error message to a log file when a division by zero exception occurs
-->logging.basicConfig(filename='error.log', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

try:
    num1 = 10
    num2 = 0
    result = num1 / num2
    print(result)

except ZeroDivisionError as e:
    logging.error("Division by zero occurred.",e)
    logging.shutdown()



Q7) How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module
import logging

# Configure logging
logging.basicConfig(filename='error.log', level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s')

logging.info("this is info")
logging.warning("warning is final call")
logging.error("u donelots of mistake")
logging.shutdown()


Q8)Write a program to handle a file opening error using exception handling
-->try:
    with open("devera.txt","r") as f:
        f.read()
except FileNotFoundError as e:
    print("file not found",e)


Q9)How can you read a file line by line and store its content in a list in Python
f = open("india.txt","w")
f.write("hello\n")
f.write("team india\n")
f.write("habibi\n")
f.write("couragesious\n")
f.write("aaaknsw\n")
f.close()
f = open("india.txt","r")
print(f.readlines())

Q10)How can you append data to an existing file in Python
-->
with open("devera.txt","a") as f:
  f.write("hello")
  f.write("team india\n")
  f.write("habibi\n")
  f.write("couragesious\n")
  f.write("aaaknsw\n")
  f.close()

Q11)Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist

a = {"akash":"name","palce":"hyderabad"}
print(a.keys())


try:
    print(a["hello"])
except KeyError as d:
    print("key doesnot exist ", d)

Q12)Write a program that demonstrates using multiple except blocks to handle different types of exceptions
try:
    #5/0
    5/"33"
except (ZeroDivisionError) as ss:
    print("based upon the error it will be result", ss)
except (TypeError) as cc:
    print("based upon the error it will be result", cc)

Q13)How would you check if a file exists before attempting to read it in Python
f = open("ff.txt","r")
print(f.mode)

Q14)Write a program that uses the logging module to log both informational and error messages
logging.basicConfig(filename = "rrr.log",level = logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
logging.info("hi hello nanu me info ni")
logging.error("anni sarulu chapali ra ungaaaa")
logging.shutdown()

Q15)Write a Python program that prints the content of a file and handles the case when the file is empty
import os
with open("hindu.txt","w") as no:
    no.write("")
    no.close()

if (os.path.getsize("hindu.txt") == 0):
    print("file is empty")
else:
    print("something is their in this")








Q16) Demonstrate how to use memory profiling to check the memory usage of a small program
import os
import cProfile
def fun():

    logging.basicConfig(filename = "rrr.log",level = logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
    logging.info("hi hello nanu me info ni")
    logging.error("anni sarulu chapali ra ungaaaa")
    logging.shutdown()
print(cProfile.run("fun()"))

Q17)Write a Python program to create and write a list of numbers to a file, one number per line
data = [1,2,3,4,5]
with open("devara.txt","a") as hh:
    for i in data:
       hh.write(f"{i}\n")


with open("devara.txt","r") as hh:
    for i in hh:
     print(i)

Q18)How would you implement a basic logging setup that logs to a file with rotation after 1MB?
-->import logging
from logging.handlers import RotatingFileHandler

# Configure logging with file rotation
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)  # Set the desired logging level

# Create a RotatingFileHandler with 1MB max size and 5 backups
handler = RotatingFileHandler('my_app.log', maxBytes=1024*1024, backupCount=5)
handler.setFormatter(logging.Formatter('%(asctime)s - %(levelname)s - %(message)s'))

# Add the handler to the logger
logger.addHandler(handler)

# Example usage
logger.info("This is an informational message.")
logger.warning("This is a warning message.")
logger.error("This is an error message.")

Q19)Write a program that handles both IndexError and KeyError using a try-except block
list = [1,2,3,4]
a = {"akash":"name","palce":"hyderabad"}
try:

    print(a[2])
except KeyError as f:
    print("error occured due to the key is not present at that index", f)

try:

    print(list[4])
except IndexError as d:
    print("this is an index error because index not their",d)


Q20)How would you open a file and read its contents using a context manager in Python
a = open("devara.txt","r")
print(a.read())


Q21)Write a Python program that reads a file and prints the number of occurrences of a specific word
specific_word = "1\n"
count = 0
with open("devara.txt","r") as kgf:
    a = kgf.readlines()
    print(a)
    for i in a:
        if i == specific_word:
            count = count + 1



print(count)










Q22)How can you check if a file is empty before attempting to read its contents
import os
with open("hindu.txt","w") as no:
    no.write("")
    no.close()

if (os.path.getsize("hindu.txt") == 0):
    print("file is empty")
else:
    print("something is their in this")

Q23)Write a Python program that writes to a log file when an error occurs during file handling
logging.basicConfig(filename='error.log', level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s')
try:
    with open("hhh.txt","r") as f:
        f.read()


except  FileNotFoundError as e:
    logging.error("file is not found.",e)
    logging.shutdown()















'''
# Out:
# '\nPRACTICAL QUESTIONS:\n\nQ1)How can you open a file for writing in Python and write a string to it\nwith open("exe.txt","w") as f:\n  f.write("hello ds team")\n\nQ2) Write a Python program to read the contents of a file and print each line\nwith open("fil.txt","r") as f:\n    print(f.readlines())\n\nQ3)How would you handle a case where the file doesn\'t exist while trying to open it for reading\ntry:\n    with open("devera.txt","r") as f:\n        f.read()\nexcept FileNotFoundError as e:\n    print("file not found",e)\n\nQ4)Write a Python script that reads from one file and writes its content to another file\n\nQ5)How would you catch and handle division by zero error in Python?\n-->\ntry:\n    3/0\nexcept ZeroDivisionError as d:\n    print("this is a error ", d)\n\nQ6)Write a Python program that logs an error message to a log file when a division by zero exception occurs\n-->logging.basicConfig(filename=\'error.log\', level=logging.ERROR, \n                    format=\'%(asctime)s 
# ...
